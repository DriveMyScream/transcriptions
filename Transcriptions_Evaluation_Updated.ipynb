# %% [markdown]
# ## Youtube Video Link: https://www.youtube.com/watch?v=MIWtT5xdsqQ

# %% [markdown]
# ## On our platform, we use AssemblyAI and AWS transcription services; however, neither of them supports Swahili language transcription. We are exploring alternative options, but many websites do not provide support for Python SDK APIs.there is one platform, Galdia, which is simple to implement, provide rich functionality and offers good pricing options.

# %% [markdown]
# # Gladia Transcriptions

# %% [markdown]
# ![prices.png](attachment:prices.png)

# %% [markdown]
# # Swahili Transcription

# %% [markdown]
# ## The response contains a world-level timestamp. From that, we will extract only words for further evaluations. We store these words in the predicted_transcription variable.

# %%
import requests

headers = {
    'x-gladia-key': 'b76c60ca-b758-459a-a81c-ddcb881fc967',
}

files = {
    'audio_url': 'https://github.com/DriveMyScream/sample/raw/main/Swahili_Language.wav',
    'toggle_diarization': 'true',
    'language': 'swahili',
    'toggle_noise_reduction': 'true',
#    'transcription_hint': ("mkali", "kivuli", "usongeshi")
}

response = requests.post('https://api.gladia.io/audio/text/audio-transcription/', headers=headers, files=files)

# %%
response = response.json()
gladia_transcription = []
for i in range(len(response['prediction'])):
    dict_of_words = response['prediction'][i]
    open_dict = dict_of_words['words']
    for i in range (len(open_dict)):
        word = open_dict[i]['word'].strip().lower()
        gladia_transcription.append(word)

print("Total Number of transcripted words in list:", len(gladia_transcription))        
print(gladia_transcription)
# Out:
# Total Number of transcripted words in list: 370
# ...

# %% [markdown]
# ## I have taken two reference transcriptions: the first from YouTube video subtitles and the second from Voiser.

# %% [markdown]
# ## Reference transcriptions 1: Youtube Subtitles translation

# %%
reference_transcription_1 = "Na kuna na pia Pazia la Chuma sio mimi hakuna ujumbe kama huo, ni kitu ambapo iko ndani wiki 1 Hi Dani Ah yeye ni afisa wa polisi nifuate Endelea, naja, muziki, nitaanza zaidi hai kwa njia ya reli Au hiyo Minas huko ujio wa mtandao unamfanya msichana mnene familia yako siku iliniambia huo unafuu na hapo pa hewa hapa cha cha Wewe ni mjinga, Rafa alishtuka wakati mini-sketi Na kuna jamaa Rafaela hana fujo nao hapa Kireno hadi Kireno kama alivyo Tunahitaji kuja, bibi hawezi kuongeza samba ni Ni nzuri sip mwili halikutokea kwa maisha ni upendo wangu furaha na Na kuna"
reference_transcription_1 = reference_transcription_1.split(" ")
print("Total Number of words in list:", len(reference_transcription_1))        
print(reference_transcription_1)
# Out:
# Total Number of words in list: 103
# ['Na', 'kuna', 'na', 'pia', 'Pazia', 'la', 'Chuma', 'sio', 'mimi', 'hakuna', 'ujumbe', 'kama', 'huo,', 'ni', 'kitu', 'ambapo', 'iko', 'ndani', 'wiki', '1', 'Hi', 'Dani', 'Ah', 'yeye', 'ni', 'afisa', 'wa', 'polisi', 'nifuate', 'Endelea,', 'naja,', 'muziki,', 'nitaanza', 'zaidi', 'hai', 'kwa', 'njia', 'ya', 'reli', 'Au', 'hiyo', 'Minas', 'huko', 'ujio', 'wa', 'mtandao', 'unamfanya', 'msichana', 'mnene', 'familia', 'yako', 'siku', 'iliniambia', 'huo', 'unafuu', 'na', 'hapo', 'pa', 'hewa', 'hapa', 'cha', 'cha', 'Wewe', 'ni', 'mjinga,', 'Rafa', 'alishtuka', 'wakati', 'mini-sketi', 'Na', 'kuna', 'jamaa', 'Rafaela', 'hana', 'fujo', 'nao', 'hapa', 'Kireno', 'hadi', 'Kireno', 'kama', 'alivyo', 'Tunahitaji', 'kuja,', 'bibi', 'hawezi', 'kuongeza', 'samba', 'ni', 'Ni', 'nzuri', 'sip', 'mwili', 'halikutokea', 'kwa', 'maisha', 'ni', 'upendo', 'wangu', 'furaha', 'na', 'Na', 'kuna']

# %% [markdown]
# ## Reference transcriptions 2: Voiser transcription

# %%
reference_transcription_2 = "Habari ya kushinda labda yako salama na leo umekatili chini kama kawaida. Unajua lazima nitilie ulinzi mkali hapa maana yake yote ni mali ya dhamani. Nimefikiri utaniambia pengine kuna joto ama kizuli kivuli mm-hmm tukitizama hali ya anga iko msema kabisa hamna joto jingi hamna baridi hivyo ni hali nyingine nzuri kabisa hebu jihadhari na tunaongea kuna jua na hivi karibuni tutakosa mboga tutaanza kuna nyanya eeh hata tu kila nyanya siwezi vitunguu vitakuwa wako kwa wingi. Haya nimeambiwa kusongesha hizi tunakula ndani tafadhali ndani amesema wajua ni nani allah mkubwa sio sisi ni mkali kama kawaida asema hakuwa hatufanyi vipasavyo hapa tunajua yeye huwa hapendezi tunapo kumzika hata kidogo pole kwa hayo hamna shida. Asante haya. Chini ya bei gani wewe hebu njoo unisaidie hapa nje na haja lakini mechi ikamilike wapata malipo gani kwa hayo hawajali nini mimi najali. Tafadhali ngoja wajue kitakacho nitendea mimi na familia yangu nikipoteza kazini wajua jinsi mkubwa alivyo. Zao la sawa. Harakisha. Hebu chukua hiyo hapo. Na nzito. Kwani mimi mbaya? Hebu. Shika hata hii hapa. Eeh ni mechi kweli lakini cameroon yapoteza timu zangu zote zinapoteza ni kawaida ni wa europa ama wa Brazil tu ndio wanaweza chukua dimba hili eti nini hili ni kombe la dunia la bara la Afrika huu ni wakati wetu bali timu ya Afrika hakuna hata 1 inayo nawili wape 1 wape muda muda kawaida. Unajua Waafrika huwa hawakosi. Cha kujitetea nacho mambo yamebadilika ghana wana kocha kutoka uropa wachezaji kama mashina drogba ana wawili sana europa mambo yamebadilika ukitizama mtu kama etoo yule vya wafanya vizuri kwa sababu wanalipwa mamilioni ya fedha kutoka huko europa akija Afrika hamna lolote yeye hajj ni mtu ambaye hajivunii. Wewe george muniu usizungumze hivyo ni ukweli tu inayosema ninyi vijana sisi hamna adabu kama ni kweli nazungumza. Na mgongo wangu kweli neno asante kwa bidii yenu ooh asante kabisa. Na utamweleza mkubwa jinsi tulivyofanya kazi kwa ubunifu nitafanya hivyo na nina ujumbe kutoka kwake na muulize hivi msimu gani anayoishabikia. Pesa au hayo usimweleze chochote atakasirika hata kunizomea ah kuzomea hii unajua vijana wa siku hizi hawana hati chafu shikilia hapo asema kuwa mkimaliza kufanya haya yote nitaweza kutazama mechi iliyosalia sawa asante nimefurahia nimefurahia hebu shikilia tutachukua hii hawachukua hiyo nile asa wacha nikutolee hizi hapa najua hizi ni muhimu. Na chunga isianguke."
reference_transcription_2 = reference_transcription_2.split(" ")
print("Total Number of transcripted words in list:", len(reference_transcription_2))        
print(reference_transcription_2)
# Out:
# Total Number of transcripted words in list: 385
# ...

# %% [markdown]
# ## This Python code uses the Natural Language Toolkit (NLTK) library to calculate BLEU (Bilingual Evaluation Understudy) scores for comparing the similarity between two text sequences

# %% [markdown]
# ![bleu_score_1.png](attachment:bleu_score_1.png)

# %% [markdown]
# ![bleu_2.png](attachment:bleu_2.png)

# %% [markdown]
# ![bleu_3.png](attachment:bleu_3.png)

# %% [markdown]
# ## Calculating a BLEU score with 'gladia_transcription' and reference transcription 1, which is from YouTube video subtitles.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_1),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_1),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_1),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_1),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.04637793936624609
# bleu_score_bigrams: 0.04443152648682567
# bleu_score_trigrams: 0.039462074874976126
# bleu_score_4_grams: 0.03171416626340449

# %% [markdown]
# ## Calculating a BLEU score with 'gladia_transcription' and reference transcription 2, which is from Voiser.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_2),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_2),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_2),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gladia_transcription)], ' '.join(reference_transcription_2),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.8983824139361261
# bleu_score_bigrams: 0.8382581352761687
# bleu_score_trigrams: 0.7652586158234308
# bleu_score_4_grams: 0.6786436921101721

# %% [markdown]
# ## GCP Transcription Pricing

# %% [markdown]
# ![gcp_pricing.png](attachment:gcp_pricing.png)

# %% [markdown]
# ## GCP supports two Swahili language transcriptions: the first one is Swahili-Kenya, and the other is Swahili-Tanzania.

# %% [markdown]
# ## 1) Swahili (Kenya)

# %%
from google.oauth2 import service_account
from google.cloud import speech

# %%
trasncription = []

client_file = 'meetminutesbackend.json'
credentials = service_account.Credentials.from_service_account_file(client_file)
client = speech.SpeechClient(credentials=credentials)

gcs_uri= 'gs://meetminutes/Swahili_Language.wav'
config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=44100, 
    language_code='sw-KE'
    )
audio = speech.RecognitionAudio(uri=gcs_uri)
operation = client.long_running_recognize(config=config, audio=audio)

print("Waiting for operation to complete...")
response = operation.result(timeout=120)

for result in response.results:
    trasncription.append(result.alternatives[0].transcript)
# Out:
# Waiting for operation to complete...

# %%
gcp_trasncription = []
for sentence in trasncription:
    words = sentence.split(" ")
    gcp_trasncription.extend(words)
    
print("Total Number of transcripted words in list:", len(gcp_trasncription))        
print(gcp_trasncription)
# Out:
# Total Number of transcripted words in list: 144
# ...

# %% [markdown]
# ## Calculating a BLEU score with 'gcp_transcription' and reference transcription 1, which is from YouTube video subtitles.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.5690249801006099
# bleu_score_bigrams: 0.504532443873608
# bleu_score_trigrams: 0.4091281547939028
# bleu_score_4_grams: 0.2940010346355584

# %% [markdown]
# ## Calculating a BLEU score with 'gcp_transcription' and reference transcription 2, which is from Voiser.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.3533803401078391
# bleu_score_bigrams: 0.34526928363083725
# bleu_score_trigrams: 0.3304307890531357
# bleu_score_4_grams: 0.29754471912139363

# %% [markdown]
# ## 2) Swahili (Tanzania)

# %%
trasncription = []

client_file = 'meetminutesbackend.json'
credentials = service_account.Credentials.from_service_account_file(client_file)
client = speech. SpeechClient(credentials=credentials)

gcs_uri= 'gs://meetminutes/Swahili_Language.wav'
config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=44100, 
    language_code='sw-TZ'
    )
audio = speech.RecognitionAudio(uri=gcs_uri)
operation = client.long_running_recognize(config=config, audio=audio)

print("Waiting for operation to complete...")
response = operation.result(timeout=120)

for result in response.results:
    trasncription.append(result.alternatives[0].transcript)
# Out:
# Waiting for operation to complete...

# %%
gcp_trasncription = []
for sentence in trasncription:
    words = sentence.split(" ")
    gcp_trasncription.extend(words)
    
print("Total Number of transcripted words in list:", len(gcp_trasncription))        
print(gcp_trasncription)
# Out:
# Total Number of transcripted words in list: 144
# ...

# %% [markdown]
# ## Calculating a BLEU score with 'gcp_transcription' and reference transcription 1, which is from YouTube video subtitles.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_1),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.5690249801006099
# bleu_score_bigrams: 0.504532443873608
# bleu_score_trigrams: 0.4091281547939028
# bleu_score_4_grams: 0.2940010346355584

# %% [markdown]
# ## Calculating a BLEU score with 'gcp_transcription' and reference transcription 2, which is from Voiser.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

bleu_score_unigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(1, 0, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_bigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.5, 0.5, 0, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_trigrams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.33, 0.33, 0.33, 0),
                          smoothing_function=SmoothingFunction().method4)

bleu_score_4_grams = sentence_bleu([' '.join(gcp_trasncription)], ' '.join(reference_transcription_2),
                          weights=(0.25, 0.25, 0.25, 0.25),
                          smoothing_function=SmoothingFunction().method4)

print(f'bleu_score_unigrams: {bleu_score_unigrams}')
print(f'bleu_score_bigrams: {bleu_score_bigrams}')
print(f'bleu_score_trigrams: {bleu_score_trigrams}')
print(f'bleu_score_4_grams: {bleu_score_4_grams}')
# Out:
# bleu_score_unigrams: 0.3533803401078391
# bleu_score_bigrams: 0.34526928363083725
# bleu_score_trigrams: 0.3304307890531357
# bleu_score_4_grams: 0.29754471912139363

# %% [markdown]
# ## We can choose the Gladia transcription service because, when comparing the BLEU scores between Gladia and Voiser, Gladia consistently achieves a higher BLEU score for all n-grams.
