# %% [markdown]
# # Swahili Transcription

# %%
import requests

headers = {
    'x-gladia-key': 'f73673b2-2809-4232-9142-9b210bae0231',
}

files = {
    'audio_url': 'https://github.com/DriveMyScream/sample/raw/main/Swahili_Language.wav',
    'toggle_diarization': 'true',
    'language': 'swahili',
    'toggle_noise_reduction': 'true',
#    'transcription_hint': ("mkali", "kivuli", "usongeshi")
}

response = requests.post('https://api.gladia.io/audio/text/audio-transcription/', headers=headers, files=files)
print(response.json())
# Out:
# {'prediction': [{'words': [{'word': 'Kama', 'time_begin': 17.030469999999998, 'time_end': 17.210559999999997, 'confidence': 0.87}, {'word': ' kawari', 'time_begin': 17.31062, 'time_end': 17.61077, 'confidence': 0.71}, {'word': ' onjela,', 'time_begin': 17.630779999999998, 'time_end': 17.91093, 'confidence': 0.67}], 'language': 'sw', 'transcription': 'Kama kawari onjela,', 'confidence': 0.4900000000000001, 'time_begin': 17.030469999999998, 'time_end': 17.91093, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' lazima', 'time_begin': 17.95095, 'time_end': 18.251109999999997, 'confidence': 0.78}, {'word': ' nitiya', 'time_begin': 18.311139999999998, 'time_end': 18.591279999999998, 'confidence': 0.59}, {'word': ' ulinzi', 'time_begin': 18.65131, 'time_end': 19.031509999999997, 'confidence': 0.63}, {'word': ' mkali', 'time_begin': 19.07153, 'time_end': 19.51176, 'confidence': 0.93}, {'word': ' yapa.', 'time_begin': 19.531769999999998, 'time_end': 19.83193, 'confidence': 0.52}], 'language': 'sw', 'transcription': 'lazima nitiya ulinzi mkali yapa.', 'confidence': 0.4900000000000001, 'time_begin': 17.95095, 'time_end': 19.83193, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' Anake', 'time_begin': 20.17211, 'time_end': 20.51229, 'confidence': 0.51}, {'word': ' yio', 'time_begin': 20.55231, 'time_end': 20.71239, 'confidence': 0.51}, {'word': ' tenimali', 'time_begin': 20.79243, 'time_end': 21.3127, 'confidence': 0.82}, {'word': ' ya', 'time_begin': 21.3127, 'time_end': 21.432769999999998, 'confidence': 0.75}, {'word': ' zamani.', 'time_begin': 21.47279, 'time_end': 21.89301, 'confidence': 0.75}], 'language': 'sw', 'transcription': 'Anake yio tenimali ya zamani.', 'confidence': 0.4900000000000001, 'time_begin': 20.17211, 'time_end': 21.89301, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' Nime', 'time_begin': 22.29321, 'time_end': 22.473309999999998, 'confidence': 0.88}, {'word': ' piruta', 'time_begin': 22.53334, 'time_end': 22.93355, 'confidence': 0.84}, {'word': ' niambia', 'time_begin': 22.95356, 'time_end': 23.2337, 'confidence': 0.76}, {'word': ' keningine', 'time_begin': 23.27373, 'time_end': 23.63391, 'confidence': 0.59}, {'word': ' kuna', 'time_begin': 23.67393, 'time_end': 23.87404, 'confidence': 0.84}, {'word': ' joto,', 'time_begin': 23.974089999999997, 'time_end': 24.31427, 'confidence': 0.85}], 'language': 'sw', 'transcription': 'Nime piruta niambia keningine kuna joto,', 'confidence': 0.4900000000000001, 'time_begin': 22.29321, 'time_end': 24.31427, 'speaker': 1, 'channel': 'channel_0'}, {'words': [{'word': ' ama', 'time_begin': 24.47435, 'time_end': 24.63443, 'confidence': 0.93}, {'word': ' kizuli', 'time_begin': 24.71448, 'time_end': 25.09467, 'confidence': 0.9}, {'word': ' kivuli.', 'time_begin': 25.15471, 'time_end': 25.63496, 'confidence': 0.89}], 'language': 'sw', 'transcription': 'ama kizuli kivuli.', 'confidence': 0.4900000000000001, 'time_begin': 24.47435, 'time_end': 25.63496, 'speaker': 1, 'channel': 'channel_0'}, {'words': [{'word': ' Kukitiza', 'time_begin': 26.315309999999997, 'time_end': 26.75554, 'confidence': 0.19}, {'word': ' maalianga,', 'time_begin': 26.83558, 'time_end': 27.53595, 'confidence': 0.24}], 'language': 'sw', 'transcription': 'Kukitiza maalianga,', 'confidence': 0.4900000000000001, 'time_begin': 26.315309999999997, 'time_end': 27.53595, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' yiko', 'time_begin': 27.55596, 'time_end': 27.73605, 'confidence': 0.19}, {'word': ' mchema', 'time_begin': 27.796079999999996, 'time_end': 28.13626, 'confidence': 0.36}, {'word': ' kabisa,', 'time_begin': 28.23631, 'time_end': 28.71656, 'confidence': 0.7}], 'language': 'sw', 'transcription': 'yiko mchema kabisa,', 'confidence': 0.4900000000000001, 'time_begin': 27.55596, 'time_end': 28.71656, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' mna', 'time_begin': 28.81662, 'time_end': 28.9767, 'confidence': 0.4}, {'word': ' joto', 'time_begin': 29.036 ...

# %%
response = response.json()
predicted_transcription = []
for i in range(len(response['prediction'])):
    dict_of_words = response['prediction'][i]
    open_dict = dict_of_words['words']
    for i in range (len(open_dict)):
        word = open_dict[i]['word'].strip().lower()
        predicted_transcription.append(word)

print("Total Number of transcripted words in list:", len(predicted_transcription))        
print(predicted_transcription)
# Out:
# Total Number of transcripted words in list: 369
# ['kama', 'kawari', 'onjela,', 'lazima', 'nitiya', 'ulinzi', 'mkali', 'yapa.', 'anake', 'yio', 'tenimali', 'ya', 'zamani.', 'nime', 'piruta', 'niambia', 'keningine', 'kuna', 'joto,', 'ama', 'kizuli', 'kivuli.', 'kukitiza', 'maalianga,', 'yiko', 'mchema', 'kabisa,', 'mna', 'joto', 'tingia,', 'mna', 'barili.', 'nihalingine', 'nzuri', 'kabisa.', 'he,', 'buji', 'ya', 'dhali', 'na', 'kilunongia.', 'kunajua.', 'na', 'hivi', 'saribuni,', 'tsakosa', 'mboga', 'tsakula', 'nyanya.', 'he?', 'asa', 'atukila', 'nyanya,', 'tevi', 'tungu', 'vita', 'kuwako', 'kwa', 'wingi', 'hai,', 'ani', 'mambuo', 'usongeshi', 'hizi,', 'tunakulia', 'ndani', 'takadali', 'nami', 'yame', 'sema?', 'wajua', 'ni', 'nani?', 'aaaa,', 'mkugwa', 'siyo?', 'nimkali', 'o,', 'kawaida', 'asema', 'kuwa', 'tufanyi', 'vipasavyo', 'hapa', 'unajua', 'ye', 'hua', 'pendezi,', 'tunapofumzika', 'hataki', 'dogo', 'pole', 'kwa', 'hayo', 'amna', 'shida', 'asante', 'hai', 'wewe,', 'ebu', 'njoo', 'unisaidia', 'hapa', 'nje', 'naja,', 'ya', 'kuri', 'mechika', 'milite', 'wapata', 'malipo', 'gani', 'kwa', 'hayo?', 'wewa', 'jali', 'mimi', 'mimi', 'na', 'jali', 'tafadali', 'ngoja', 'wejua', 'kitakacho', 'nitendekia', 'mimi', 'na', 'familia', 'ngu', 'nikipoteza', 'kazi', 'wejua', 'jinzi', 'mkubwa', 'livyo', 'zawa,', 'zawa', 'arakisha', 'ebu,', 'chukwe', 'yu', 'hafu', 'menzijo', 'kwanini', 'ni', 'mbaya', 'ebu', 'shiku', 'hata', 'yata', 'nchini', 'kwa', 'meru', 'ni', 'ya', 'poteza.', 'kimli', 'sangu', 'zote', 'zao', 'poteza.', 'ni', 'kawaida,', 'ni', 'wa', 'europa', 'ama', 'wa', 'brazil', 'tuu.', 'ndiyo', 'wanaweza', 'chikuwa', 'di', 'baili.', 'e', 'chini', 'ni?', 'nchini', 'kome', 'la', 'dunya', 'la', 'barra', 'la', 'afrika.', 'unu', 'wakatiwechu.', 'bali,', 'team', 'ya', 'afrika', 'hakuna', 'ata', 'moja', 'inayo', 'na', 'wiri.', 'wape', 'mda.', 'mda,', 'kawaida.', 'unajwa,', 'wa', 'afrika', 'uwa', 'wakosi,', 'cha', 'kujitetea', 'na', 'cho.', 'mambo', 'ya', 'mbadilika.', 'mgana', 'walakochi', 'kutoka', 'europa.', 'watizaji', 'kama', 'tunadrogba,', 'anawiri', 'sana', 'europa.', 'mwame', 'abadlika.', 'ukitizwa', 'mwamtu', 'kama', 'eto,', 'yule', 'yafanya', 'vizuri', 'kwa', 'sababu', 'wanalipua', 'mamilioni', 'ya', 'fedha', 'kutoka', 'huko', 'europa.', 'hakija', 'afrika,', 'hamna', 'nolote.', 'ye,', 'ha...', 'ni', 'mtu', 'amba', 'hajivuni.', 'kwa', 'hivyo', 'mbili?', 'na', 'mbongo', 'wamu', 'kwenye', 'mnemo...', 'asante', 'kwa', 'bidienu.', 'o,', 'asante', 'kabisa.', 'na...', 'uta', 'muenze', 'mkubwa.', 'jinti', 'tulivyo', 'fanya', 'kazi', 'kwa', 'bidienu.', 'nitafanya', 'hivyo,', 'na', 'ninaujumbe', 'kutoka', 'kwa', 'kwe.', 'na,', 'mulize', 'vi,', 'nchumgane', 'nao', 'shabikiya.', 'naa,', 'we', 'mtahu', 'hayo.', 'ufi', 'muenze', 'chote,', 'ataka', 'sirika.', 'ataka', 'unizomea.', 'ha,', 'kuzomei.', 'unajeo', 'dijana', 'wa', 'sikuizia', 'wana', 'adhavo.', 'shikilia', 'hapo.', 'asema', 'wakua', 'mkimaliza', 'kufanya', 'haya', 'yote,', 'nitaiza', 'kutazama', 'mechi', 'liyo', 'salia.', 'sawa?', 'asante.', 'mnafraya.', 'mnafraya.', 'ebu,', 'shikili', 'ya', 'ute.', 'tukuwai.', 'na', 'wacha', 'wachikwanya', 'mendebe.', 'haa,', 'kaa.', 'wata', 'nipulei', 'hizi', 'yapa.', 'na', 'jua', 'hizi', 'mnahimu.', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mbili', 'mb']

# %%
' '.join(predicted_transcription)
# Out:
# 'kama kawari onjela, lazima nitiya ulinzi mkali yapa. anake yio tenimali ya zamani. nime piruta niambia keningine kuna joto, ama kizuli kivuli. kukitiza maalianga, yiko mchema kabisa, mna joto tingia, mna barili. nihalingine nzuri kabisa. he, buji ya dhali na kilunongia. kunajua. na hivi saribuni, tsakosa mboga tsakula nyanya. he? asa atukila nyanya, tevi tungu vita kuwako kwa wingi hai, ani mambuo usongeshi hizi, tunakulia ndani takadali nami yame sema? wajua ni nani? aaaa, mkugwa siyo? nimkali o, kawaida asema kuwa tufanyi vipasavyo hapa unajua ye hua pendezi, tunapofumzika hataki dogo pole kwa hayo amna shida asante hai wewe, ebu njoo unisaidia hapa nje naja, ya kuri mechika milite wapata malipo gani kwa hayo? wewa jali mimi mimi na jali tafadali ngoja wejua kitakacho nitendekia mimi na familia ngu nikipoteza kazi wejua jinzi mkubwa livyo zawa, zawa arakisha ebu, chukwe yu hafu menzijo kwanini ni mbaya ebu shiku hata yata nchini kwa meru ni ya poteza. kimli sangu zote zao poteza. ni kawaida, ni wa europa ama wa brazil tuu. ndiyo wanaweza chikuwa di baili. e chini ni? nchini kome la dunya la barra la afrika. unu wakatiwechu. bali, team ya afrika hakuna ata moja inayo na wiri. wape mda. mda, kawaida. unajwa, wa afrika uwa wakosi, cha kujitetea na cho. mambo ya mbadilika. mgana walakochi kutoka europa. watizaji kama tunadrogba, anawiri sana europa. mwame abadlika. ukitizwa mwamtu kama eto, yule yafanya vizuri kwa sababu wanalipua mamilioni ya fedha kutoka huko europa. hakija afrika, hamna nolote. ye, ha... ni mtu amba hajivuni. kwa hivyo mbili? na mbongo wamu kwenye mnemo... asante kwa bidienu. o, asante kabisa. na... uta muenze mkubwa. jinti tulivyo fanya kazi kwa bidienu. nitafanya hivyo, na ninaujumbe kutoka kwa kwe. na, mulize vi, nchumgane nao shabikiya. naa, we mtahu hayo. ufi muenze chote, ataka sirika. ataka unizomea. ha, kuzomei. unajeo dijana wa sikuizia wana adhavo. shikilia hapo. asema wakua mkimaliza kufanya haya yote, nitaiza kutazama mechi liyo salia. sawa? asante. mnafraya. mnafraya. ebu, shikili ya ute. tukuwai. na wacha wachikwanya mendebe. haa, kaa. wata nipulei hizi yapa. na jua hizi mnahimu. mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mbili mb'

# %% [markdown]
# ## https://voiser.net/account/speech-to-text/3Y4OGLGU

# %%
actual_transcription = "Habari ya kushinda labda yako salama na leo umekatili chini kama kawaida. Unajua lazima nitilie ulinzi mkali hapa maana yake yote ni mali ya dhamani. Nimefikiri utaniambia pengine kuna joto ama kizuli kivuli mm-hmm tukitizama hali ya anga iko msema kabisa hamna joto jingi hamna baridi hivyo ni hali nyingine nzuri kabisa hebu jihadhari na tunaongea kuna jua na hivi karibuni tutakosa mboga tutaanza kuna nyanya eeh hata tu kila nyanya siwezi vitunguu vitakuwa wako kwa wingi. Haya nimeambiwa kusongesha hizi tunakula ndani tafadhali ndani amesema wajua ni nani allah mkubwa sio sisi ni mkali kama kawaida asema hakuwa hatufanyi vipasavyo hapa tunajua yeye huwa hapendezi tunapo kumzika hata kidogo pole kwa hayo hamna shida. Asante haya. Chini ya bei gani wewe hebu njoo unisaidie hapa nje na haja lakini mechi ikamilike wapata malipo gani kwa hayo hawajali nini mimi najali. Tafadhali ngoja wajue kitakacho nitendea mimi na familia yangu nikipoteza kazini wajua jinsi mkubwa alivyo. Zao la sawa. Harakisha. Hebu chukua hiyo hapo. Na nzito. Kwani mimi mbaya? Hebu. Shika hata hii hapa. Eeh ni mechi kweli lakini cameroon yapoteza timu zangu zote zinapoteza ni kawaida ni wa europa ama wa Brazil tu ndio wanaweza chukua dimba hili eti nini hili ni kombe la dunia la bara la Afrika huu ni wakati wetu bali timu ya Afrika hakuna hata 1 inayo nawili wape 1 wape muda muda kawaida. Unajua Waafrika huwa hawakosi. Cha kujitetea nacho mambo yamebadilika ghana wana kocha kutoka uropa wachezaji kama mashina drogba ana wawili sana europa mambo yamebadilika ukitizama mtu kama etoo yule vya wafanya vizuri kwa sababu wanalipwa mamilioni ya fedha kutoka huko europa akija Afrika hamna lolote yeye hajj ni mtu ambaye hajivunii. Wewe george muniu usizungumze hivyo ni ukweli tu inayosema ninyi vijana sisi hamna adabu kama ni kweli nazungumza. Na mgongo wangu kweli neno asante kwa bidii yenu ooh asante kabisa. Na utamweleza mkubwa jinsi tulivyofanya kazi kwa ubunifu nitafanya hivyo na nina ujumbe kutoka kwake na muulize hivi msimu gani anayoishabikia. Pesa au hayo usimweleze chochote atakasirika hata kunizomea ah kuzomea hii unajua vijana wa siku hizi hawana hati chafu shikilia hapo asema kuwa mkimaliza kufanya haya yote nitaweza kutazama mechi iliyosalia sawa asante nimefurahia nimefurahia hebu shikilia tutachukua hii hawachukua hiyo nile asa wacha nikutolee hizi hapa najua hizi ni muhimu. Na chunga isianguke."
actual_transcription = actual_transcription.split(" ")
print("Total Number of transcripted words in list:", len(actual_transcription))        
print(actual_transcription)
# Out:
# Total Number of transcripted words in list: 385
# ['Habari', 'ya', 'kushinda', 'labda', 'yako', 'salama', 'na', 'leo', 'umekatili', 'chini', 'kama', 'kawaida.', 'Unajua', 'lazima', 'nitilie', 'ulinzi', 'mkali', 'hapa', 'maana', 'yake', 'yote', 'ni', 'mali', 'ya', 'dhamani.', 'Nimefikiri', 'utaniambia', 'pengine', 'kuna', 'joto', 'ama', 'kizuli', 'kivuli', 'mm-hmm', 'tukitizama', 'hali', 'ya', 'anga', 'iko', 'msema', 'kabisa', 'hamna', 'joto', 'jingi', 'hamna', 'baridi', 'hivyo', 'ni', 'hali', 'nyingine', 'nzuri', 'kabisa', 'hebu', 'jihadhari', 'na', 'tunaongea', 'kuna', 'jua', 'na', 'hivi', 'karibuni', 'tutakosa', 'mboga', 'tutaanza', 'kuna', 'nyanya', 'eeh', 'hata', 'tu', 'kila', 'nyanya', 'siwezi', 'vitunguu', 'vitakuwa', 'wako', 'kwa', 'wingi.', 'Haya', 'nimeambiwa', 'kusongesha', 'hizi', 'tunakula', 'ndani', 'tafadhali', 'ndani', 'amesema', 'wajua', 'ni', 'nani', 'allah', 'mkubwa', 'sio', 'sisi', 'ni', 'mkali', 'kama', 'kawaida', 'asema', 'hakuwa', 'hatufanyi', 'vipasavyo', 'hapa', 'tunajua', 'yeye', 'huwa', 'hapendezi', 'tunapo', 'kumzika', 'hata', 'kidogo', 'pole', 'kwa', 'hayo', 'hamna', 'shida.', 'Asante', 'haya.', 'Chini', 'ya', 'bei', 'gani', 'wewe', 'hebu', 'njoo', 'unisaidie', 'hapa', 'nje', 'na', 'haja', 'lakini', 'mechi', 'ikamilike', 'wapata', 'malipo', 'gani', 'kwa', 'hayo', 'hawajali', 'nini', 'mimi', 'najali.', 'Tafadhali', 'ngoja', 'wajue', 'kitakacho', 'nitendea', 'mimi', 'na', 'familia', 'yangu', 'nikipoteza', 'kazini', 'wajua', 'jinsi', 'mkubwa', 'alivyo.', 'Zao', 'la', 'sawa.', 'Harakisha.', 'Hebu', 'chukua', 'hiyo', 'hapo.', 'Na', 'nzito.', 'Kwani', 'mimi', 'mbaya?', 'Hebu.', 'Shika', 'hata', 'hii', 'hapa.', 'Eeh', 'ni', 'mechi', 'kweli', 'lakini', 'cameroon', 'yapoteza', 'timu', 'zangu', 'zote', 'zinapoteza', 'ni', 'kawaida', 'ni', 'wa', 'europa', 'ama', 'wa', 'Brazil', 'tu', 'ndio', 'wanaweza', 'chukua', 'dimba', 'hili', 'eti', 'nini', 'hili', 'ni', 'kombe', 'la', 'dunia', 'la', 'bara', 'la', 'Afrika', 'huu', 'ni', 'wakati', 'wetu', 'bali', 'timu', 'ya', 'Afrika', 'hakuna', 'hata', '1', 'inayo', 'nawili', 'wape', '1', 'wape', 'muda', 'muda', 'kawaida.', 'Unajua', 'Waafrika', 'huwa', 'hawakosi.', 'Cha', 'kujitetea', 'nacho', 'mambo', 'yamebadilika', 'ghana', 'wana', 'kocha', 'kutoka', 'uropa', 'wachezaji', 'kama', 'mashina', 'drogba', 'ana', 'wawili', 'sana', 'europa', 'mambo', 'yamebadilika', 'ukitizama', 'mtu', 'kama', 'etoo', 'yule', 'vya', 'wafanya', 'vizuri', 'kwa', 'sababu', 'wanalipwa', 'mamilioni', 'ya', 'fedha', 'kutoka', 'huko', 'europa', 'akija', 'Afrika', 'hamna', 'lolote', 'yeye', 'hajj', 'ni', 'mtu', 'ambaye', 'hajivunii.', 'Wewe', 'george', 'muniu', 'usizungumze', 'hivyo', 'ni', 'ukweli', 'tu', 'inayosema', 'ninyi', 'vijana', 'sisi', 'hamna', 'adabu', 'kama', 'ni', 'kweli', 'nazungumza.', 'Na', 'mgongo', 'wangu', 'kweli', 'neno', 'asante', 'kwa', 'bidii', 'yenu', 'ooh', 'asante', 'kabisa.', 'Na', 'utamweleza', 'mkubwa', 'jinsi', 'tulivyofanya', 'kazi', 'kwa', 'ubunifu', 'nitafanya', 'hivyo', 'na', 'nina', 'ujumbe', 'kutoka', 'kwake', 'na', 'muulize', 'hivi', 'msimu', 'gani', 'anayoishabikia.', 'Pesa', 'au', 'hayo', 'usimweleze', 'chochote', 'atakasirika', 'hata', 'kunizomea', 'ah', 'kuzomea', 'hii', 'unajua', 'vijana', 'wa', 'siku', 'hizi', 'hawana', 'hati', 'chafu', 'shikilia', 'hapo', 'asema', 'kuwa', 'mkimaliza', 'kufanya', 'haya', 'yote', 'nitaweza', 'kutazama', 'mechi', 'iliyosalia', 'sawa', 'asante', 'nimefurahia', 'nimefurahia', 'hebu', 'shikilia', 'tutachukua', 'hii', 'hawachukua', 'hiyo', 'nile', 'asa', 'wacha', 'nikutolee', 'hizi', 'hapa', 'najua', 'hizi', 'ni', 'muhimu.', 'Na', 'chunga', 'isianguke.']

# %%
from nltk.translate.bleu_score import sentence_bleu

bleu_score = sentence_bleu([' '.join(predicted_transcription)], ' '.join(actual_transcription))
print(f'BLEU Score: {bleu_score}')
# Out:
# BLEU Score: 0.6791192025635526

# %%
import sacrebleu

bleu = sacrebleu.corpus_bleu([' '.join(predicted_transcription)], ' '.join(actual_transcription))
print(f'BLEU Score: {bleu.score}')
# Out:
# BLEU Score: 0.10695217750729552

# %% [markdown]
# # English Transcriptions

# %%
import requests

headers = {
    'x-gladia-key': 'f73673b2-2809-4232-9142-9b210bae0231',
}

files = {
    'audio_url': 'https://github.com/DriveMyScream/transcriptions/raw/main/english_audio_file.wav',
    'toggle_diarization': 'true',
    'language': 'english',
    'toggle_noise_reduction': 'true',
#    'transcription_hint': ("mkali", "kivuli", "usongeshi")
}

response = requests.post('https://api.gladia.io/audio/text/audio-transcription/', headers=headers, files=files)
print(response.json())
# Out:
# {'prediction': [{'words': [{'word': 'The', 'time_begin': 0.16609000000000002, 'time_end': 0.28620999999999996, 'confidence': 0.95}, {'word': ' most', 'time_begin': 0.36628, 'time_end': 0.72662, 'confidence': 1}, {'word': ' used', 'time_begin': 0.8267100000000001, 'time_end': 1.00688, 'confidence': 0.96}, {'word': ' messaging', 'time_begin': 1.04692, 'time_end': 1.44729, 'confidence': 0.99}, {'word': ' app', 'time_begin': 1.5273700000000001, 'time_end': 1.6675, 'confidence': 0.96}, {'word': ' in', 'time_begin': 1.6675, 'time_end': 1.7876100000000001, 'confidence': 0.98}, {'word': ' Southeast', 'time_begin': 1.82765, 'time_end': 2.2680599999999997, 'confidence': 1}, {'word': ' Asia', 'time_begin': 2.3281199999999997, 'time_end': 2.5883599999999998, 'confidence': 0.84}, {'word': ' was', 'time_begin': 3.28902, 'time_end': 3.42915, 'confidence': 1}, {'word': ' built', 'time_begin': 3.5292499999999998, 'time_end': 3.7094199999999997, 'confidence': 0.9}, {'word': ' by', 'time_begin': 3.74945, 'time_end': 3.86957, 'confidence': 1}, {'word': ' a', 'time_begin': 3.86957, 'time_end': 3.98968, 'confidence': 0.99}, {'word': ' young', 'time_begin': 4.04973, 'time_end': 4.26994, 'confidence': 0.97}, {'word': ' man', 'time_begin': 4.35002, 'time_end': 4.61026, 'confidence': 1}, {'word': ' born', 'time_begin': 4.93056, 'time_end': 5.11073, 'confidence': 0.91}, {'word': ' in', 'time_begin': 5.13075, 'time_end': 5.250859999999999, 'confidence': 0.96}, {'word': ' Ukraine', 'time_begin': 5.310919999999999, 'time_end': 5.75133, 'confidence': 0.65}, {'word': ' who', 'time_begin': 6.09165, 'time_end': 6.21176, 'confidence': 0.97}, {'word': ' moved', 'time_begin': 6.27182, 'time_end': 6.4519899999999994, 'confidence': 0.77}, {'word': ' to', 'time_begin': 6.4519899999999994, 'time_end': 6.51204, 'confidence': 0.46}, {'word': ' the', 'time_begin': 6.51204, 'time_end': 6.63215, 'confidence': 0.94}, {'word': ' US.', 'time_begin': 6.73225, 'time_end': 6.9724699999999995, 'confidence': 0.99}], 'language': 'en', 'transcription': 'The most used messaging app in Southeast Asia was built by a young man born in Ukraine who moved to the US.', 'confidence': 0.76, 'time_begin': 0.16609000000000002, 'time_end': 6.9724699999999995, 'speaker': 0, 'channel': 'channel_0'}, {'words': [{'word': ' And', 'time_begin': 7.973409999999999, 'time_end': 8.093520000000002, 'confidence': 0.99}, {'word': ' the', 'time_begin': 8.093520000000002, 'time_end': 8.213640000000002, 'confidence': 0.98}, {'word': ' three', 'time_begin': 8.23366, 'time_end': 8.45386, 'confidence': 0.96}, {'word': ' most', 'time_begin': 8.51392, 'time_end': 8.754140000000001, 'confidence': 0.95}, {'word': ' popular', 'time_begin': 8.79418, 'time_end': 9.17454, 'confidence': 1}, {'word': ' viral', 'time_begin': 9.254610000000001, 'time_end': 9.61495, 'confidence': 0.58}, {'word': ' games', 'time_begin': 9.67501, 'time_end': 9.93525, 'confidence': 0.99}, {'word': ' in', 'time_begin': 9.93525, 'time_end': 10.035340000000001, 'confidence': 0.99}, {'word': ' the', 'time_begin': 10.01533, 'time_end': 10.135440000000001, 'confidence': 0.98}, {'word': ' US', 'time_begin': 10.23553, 'time_end': 10.43572, 'confidence': 0.94}, {'word': ' in', 'time_begin': 10.43572, 'time_end': 10.55583, 'confidence': 0.99}, {'word': ' recent', 'time_begin': 10.63591, 'time_end': 10.95621, 'confidence': 1}, {'word': ' years', 'time_begin': 11.01626, 'time_end': 11.356580000000001, 'confidence': 0.94}, {'word': ' came', 'time_begin': 11.857050000000001, 'time_end': 12.037220000000001, 'confidence': 1}, {'word': ' from', 'time_begin': 12.07726, 'time_end': 12.21739, 'confidence': 1}, {'word': ' entrepreneurs', 'time_begin': 12.357520000000001, 'time_end': 12.95808, 'confidence': 0.76}, {'word': ' in', 'time_begin': 13.138250000000001, 'time_end': 13.258370000000001, 'confidence': 1}, {'word': ' Finland,', 'time_begin': 13.358460000000001, 'time_end': 13.818890000000001, 'confidence': 1}], 'language': 'en', 'transcription': 'And the three  ...

# %%
response = response.json()
predicted_transcription = []
for i in range(len(response['prediction'])):
    dict_of_words = response['prediction'][i]
    open_dict = dict_of_words['words']
    for i in range (len(open_dict)):
        word = open_dict[i]['word'].strip().lower()
        predicted_transcription.append(word)

print("Total Number of transcripted words in list:", len(predicted_transcription))        
print(predicted_transcription)
# Out:
# Total Number of transcripted words in list: 76
# ['the', 'most', 'used', 'messaging', 'app', 'in', 'southeast', 'asia', 'was', 'built', 'by', 'a', 'young', 'man', 'born', 'in', 'ukraine', 'who', 'moved', 'to', 'the', 'us.', 'and', 'the', 'three', 'most', 'popular', 'viral', 'games', 'in', 'the', 'us', 'in', 'recent', 'years', 'came', 'from', 'entrepreneurs', 'in', 'finland,', 'ireland', 'and', 'vietnam.', "you're", 'the', 'ones', 'building', 'the', 'next', 'google,', 'the', 'next', 'spotify,', 'the', 'next', 'tesla,', 'the', 'next...', 'well,', 'we', "don't", 'even', 'know,', 'but', 'what', 'i', 'know', 'is', 'that', 'someone', 'in', 'this', 'room', 'will', 'build', 'it.']

# %%
actual_transcription = "The most used messaging app in Southeast Asia was built by a young man born in Ukraine who moved to the US, and the three most popular viral games in the US in recent years came from entrepreneurs in Finland, Ireland and Vietnam. You're the ones building the next Google, the next Spotify, the next Tesla, the next while. We don't even know. But what I know is that someone in this room will build it. "
actual_transcription = actual_transcription.split(" ")
print("Total Number of transcripted words in list:", len(actual_transcription))        
print(actual_transcription)
# Out:
# Total Number of transcripted words in list: 77
# ['The', 'most', 'used', 'messaging', 'app', 'in', 'Southeast', 'Asia', 'was', 'built', 'by', 'a', 'young', 'man', 'born', 'in', 'Ukraine', 'who', 'moved', 'to', 'the', 'US,', 'and', 'the', 'three', 'most', 'popular', 'viral', 'games', 'in', 'the', 'US', 'in', 'recent', 'years', 'came', 'from', 'entrepreneurs', 'in', 'Finland,', 'Ireland', 'and', 'Vietnam.', "You're", 'the', 'ones', 'building', 'the', 'next', 'Google,', 'the', 'next', 'Spotify,', 'the', 'next', 'Tesla,', 'the', 'next', 'while.', 'We', "don't", 'even', 'know.', 'But', 'what', 'I', 'know', 'is', 'that', 'someone', 'in', 'this', 'room', 'will', 'build', 'it.', '']

# %%
from nltk.translate.bleu_score import sentence_bleu

bleu_score = sentence_bleu([' '.join(predicted_transcription)], ' '.join(actual_transcription))
print(f'BLEU Score: {bleu_score}')
# Out:
# BLEU Score: 0.8738085402655847

# %%
import sacrebleu

bleu = sacrebleu.corpus_bleu([' '.join(predicted_transcription)], ' '.join(actual_transcription))
print(f'BLEU Score: {bleu.score}')
# Out:
# BLEU Score: 0.5780829745424562
